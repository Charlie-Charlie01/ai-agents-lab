# %% [markdown]
# ### Jokester Agent
# This agent tells a joke about Autonomous AI Agent

# %%
# Import the necessary libraries
from dotenv import load_dotenv
load_dotenv(override=True)

# Import agents
from agents import Agent, Runner, trace

# %%
# The usual starting point
# load_dotenv(override=True)

# %%
# Make an agent with name, instructions, model
agent = Agent(name="Jokester", instructions="You are a joke teller", model="gpt-4o-mini")

# %%
# Run the joke with Runner.run(agent, prompt) then point final_output, then wrap in in a trace
with trace("Telling a joke"):
    result = await Runner.run(agent, "Tell a joke about Autonomous AI Agents")
    print(result.final_output)
# Out:
# Why did the autonomous AI agent break up with its partner?
#
# Because it couldn't find the right algorithm for love!
